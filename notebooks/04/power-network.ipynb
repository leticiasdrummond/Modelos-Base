# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiasdrummond/Modelos-Base/blob/main/notebooks/04/power-network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```{index} single: application; energy systems
# ```
# ```{index} single: solver; highs
# ```
# ```{index} pandas dataframe
# ```
# ```{index} network optimization
# ```
# ```{index} networkx
# ```
# ```{index} scenario analysis
# ```
#
# # Extra material: Energy dispatch problem
#
# To meet the energy demand, power plants run day and night across the country to produce electricity from a variety of sources such as fossil fuels and renewable energy. On the short-time scale, the best operating levels for electric power plants are derived every 15 minutes by solving the so-called *Optimal Power Flow (OPF)* model. The OPF model is an optimization problem with the objective of minimizing the total energy dispatching cost, while ensuring that the generation meets the total energy demand. Furthermore, the model takes into account many constraints, among which operational and physical constraints.

# %%
# install dependencies and select solver
# %pip install -q amplpy matplotlib networkx scipy numpy pandas

SOLVER = "highs"

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=["highs"],  # modules to install
    license_uuid="default",  # license to use
)  # instantiate AMPL object and register magics
# Out:
# Using default Community Edition License for Colab. Get yours at: https://ampl.com/ce
# Licensed to AMPL Community Edition License for the AMPL Model Colaboratory (https://ampl.com/colab).

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ## Background: Power networks and power flow physics
#
# We model the nation-wide transmission power network as a directed graph $G=(V, E)$, where $V$ represents the set of nodes (e.g., cities, industrial districts, power plants) and $E$ denotes the set of directed edges (e.g., physical transmission lines).
#
# Each node $i \in V$ has a power injection $p_i$ and demand $d_i$. The set of nodes are separated into *generator* and *load* nodes. The set of generators $\mathcal{G} \subseteq V$ corresponds to the nodes $i \in V$ for which $p_i \geq 0$ and $d_i = 0$. Each generator $i \in \mathcal{G}$ has a minimum $p_i^{\min}$ and maximum $p_i^{\max}$ production capacity. The set of load nodes $\mathcal{D} \subseteq V$ corresponds to the nodes for which $p_i = 0$ and $d_i \geq 0$. The load nodes thus correspond to the places where electricity is being consumed, e.g., cities and industrial districts. We say that supply and demand is *matched* if $\sum_{i \in V} p_i - d_i = 0$. Since we cannot store electricity in large volumes, supply must meet demand at all times, hence adjusting to it every 15 minutes by solving the OPF.
#
# Each edge $(i, j) \in E$ carries a *power flow* $f_{ij} \in R$ and has a capacity $f_{ij}^{\max} \geq 0$, i.e., the maximum power flow that it may carry. Note that our choice to model a *directed* graph is to make the modeling of the network easier. In particular, a directed edge $(i,j)$ may carry a 'negative' flow $f_{ij} < 0$, which implies that there is flow going from $j$ to $i$ where $f_{ji} = -f_{ij}$. The capacity does not depend on the direction of the flow, implying that the flow capacity constraints are given by $|f_{ij}| = |f_{ji}| \leq f_{ij}^{\max}$.
#
# One crucial difference of power flow problems compared to typical network flow problems is that the power flows cannot be controlled directly. Instead, as you might recall from high-school physics, the power flows are determined by the laws of electricity, which we will now present as the *power flow equations*. Ignore for a moment the flow capacity constraints. Let $\theta_{i} \in \mathbb{R}$ denote the *phase angle* of node $i$. For each edge $(i,j)$, let $b_{ij} > 0$ denote the *line susceptance*. Assuming that supply and demand is matched, i.e., $\sum_{i=1}^{n} p_i - d_i = 0$, the power flows $\mathbf{f} \in \mathbb{R}^{m}$ and phase angles $\mathbf{\theta} \in \mathbb{R}^{n}$ are obtained by solving the following linear system of equations:
#
# $$\begin{align}
# p_i - d_i &= \sum_{j: (i, j) \in E} f_{ij} - \sum_{j: (j, i) \in E} f_{ji}, & \forall \, i \in V,\\
#   f_{ij} &=  b_{ij}(\theta_i - \theta_j), & \forall \, (i, j) \in E.
# \end{align}$$
#
# The first set of constraints ensures flow conservation and the second set of constrations captures the flow dependency on susceptances and angle differences. The DC power flow equations admit a unique power flow solution $\mathbf{f}$ given matched power injections $\mathbf{p}$ and demand $\mathbf{d}$.
#
# For a given matched supply and demand vector $\mathbf{p}$ and $\mathbf{d}$, we can compute the power flows on the network by solving the linear equations as described above. There are exactly $|V|$ and $|E|$ equations for the $\theta_i$ variables and $f_{ij}$ variables, meaning that this system of equations admit a solution.

# %% [markdown]
# ## Optimal Power Flow
# We assumed above that the power injections $\mathbf{p}$ were given. However, in practice, the power injections need to be determined for each generator in the power network, where some types of generators may be cheaper than others. Moreover, we need to take into account operational constraints, such as the maximum flow and generator limits.
#
# On the short-time scale, the power injections are calculated for each generator by solving the so-called *Optimal Power Flow (OPF)* problem. The goal of the OPF problem is to determine a solution $(\mathbf{p}, \mathbf{f}, \mathbf{\theta})$ with minimal costs such that:
# - Supply meets demand
# - Line capacity constraints are met
# - Generator capacity constraints are met
#
# Let $c_i > 0$ be the cost associated with the production of a unit energy by generator $i$. Then, the OPF problem can be formulated as
#
# $$\begin{align}
# \begin{array}{llll}
# \min        & \sum_{i \in V} c_i p_i \\
# \text{s.t.} & \sum_{j: (i, j) \in E} f_{ij} - \sum_{j: (j, i) \in E} f_{ji} = p_i - d_i & \forall \, i \in V,\\
# & f_{ij} =  b_{ij}(\theta_i - \theta_j), & \forall \, (i, j) \in E, \\
#             & |f_{ij}| \leq  f_{ij}^{\max}    & \forall (i, j) \in E,\\
#             & p_{i}^{\min } \leq p_{i} \leq p_{i}^{\max }         & \forall i \in V, \\
#             & p_i \in \mathbb{R}_{\geq 0}        & \forall i \in V,                \\
#             & \theta_i \in \mathbb{R} & \forall i \in V, \\
#             & f_{ij} \in \mathbb{R}                 & \forall (i, j) \in E                \\
# \end{array}
# \end{align}$$
#
# For simplicity, you may assume that all load nodes do not produce energy, i.e., $p_i = p_i^{\min} = p_i^{\max} = 0$ for all $i \in \mathcal{D}$. You may therefore model $p_i$ as decision variables for all nodes (both generator and load nodes). Similarly, you may assume that all generator nodes have no demand, i.e., $d_i = 0$ for all $i \in \mathcal{G}$.
#
# To summarize, the decision variables in the OPF problem are:
# - $p_i$ power injections
# - $\theta_i$ phase angles
# - $f_{ij}$ power flows
#
# All the other quantities are instance dependent parameters.

# %% [markdown]
# ## Data

# %% [markdown]
# You will solve the OPF problem on the IEEE-118 power network, which is a standard test network consisting of 118 nodes and 179 edges. In the following, we will load the data into the notebook and provide a description of the data.

# %% [markdown]
# ### Data import

# %%
# Download the data
base_url = "https://raw.githubusercontent.com/ampl/mo-book.ampl.com/dev/notebooks/04/"
nodes_df = pd.read_csv(base_url + "nodes.csv").set_index(["node_id", "instance"])
edges_df = pd.read_csv(base_url + "edges.csv").set_index(["node_id1", "node_id2"])

# Replace 'na' by an empty string
nodes_df.fillna("", inplace=True)

# Split the initial nodes data frame by instance
nodes_by_instance = [
    y.reset_index(level=1).drop("instance", axis=1)
    for x, y in nodes_df.groupby("instance")
]
I = [{"nodes": n, "edges": edges_df} for n in nodes_by_instance]

# Initialize a network for demonstration purposes
network = I[0]

# %% [markdown]
# ### Network data

# %%
def visualize_network(network, edge_flows=None, ax=None):
    """Visualize a network instance, highlighting the generators in orange and the load buses in green."""
    plt.figure(figsize=[12, 10])
    g = nx.DiGraph(list(network["edges"].index))
    pos = nx.layout.kamada_kawai_layout(g, weight=None)

    color_mapping = {
        "solar": "#ffcb36",
        "wind": "white",
        "hydro": "#a5efff",
        "coal": "#686868",
        "gas": "#00ab4e",
        "": "#b6b6b6",
    }

    vertex2color = {
        k: color_mapping[v] for k, v in network["nodes"]["energy_type"].items()
    }
    v2c_list = [vertex2color[i] for i in g.nodes]  # Order based on networkx

    nodes = nx.draw_networkx_nodes(
        g,
        pos,
        node_size=250,
        node_color=v2c_list,
        linewidths=2,
    )
    edges = nx.draw_networkx_edges(
        g,
        pos,
        width=2,
        edge_color="#595959",
    )

    # Gives node colors
    ax = plt.gca()
    ax.collections[0].set_edgecolor("#595959")
    ax.set_axis_off()

# %%
visualize_network(network)

# %% [markdown]
# The IEEE-118 network has 18 generators, of which:
# - 2 hydro plants (cyan)
# - 4 coal plants (dark gray)
# - 4 solarfarms (yellow)
# - 2 windmills (white)
# - 6 gas plants (green)
#
# Moreover, the network has 100 load nodes (gray). Each node has the following parameters:
# - `node_id`
# - `d`: demand
# - `p_min`: minimum production capacity
# - `p_max`: maximum production capacity
# - `c_var`: variable production costs
# - `is_generator`: boolean value to indicate whether the node is a generator or not
# - `energy_type`: the type of energy used for electricity production

# %% [markdown]
# All generator nodes can filtered by the `is_generator` parameter. All generators have a zero demand $d_i=0$. For the renewable energy sources (i.e., hydro, solar and wind) there are no variable costs `c_var`. For solar and wind, the production is fixed, i.e., `p_min = p_max`, meaning that all available solar and wind energy must be produced.

# %%
example_nodes = network["nodes"]
example_nodes[example_nodes.is_generator]
# Out:
#            d       p_min        p_max      c_var  is_generator energy_type
# node_id
# 9        0.0    0.000000   400.000000   0.000000          True       hydro
# 11       0.0    0.000000   200.000000   0.000000          True       hydro
# 24       0.0    0.000000   397.800000  28.948321          True        coal
# 25       0.0    0.000000   873.000000  22.220980          True        coal
# 30       0.0    0.000000   612.000000  25.993982          True        coal
# 45       0.0    0.000000   720.000000  24.202306          True        coal
# 48       0.0    0.000000     0.000000   0.000000          True       solar
# 53       0.0    0.000000     0.000000   0.000000          True       solar
# 58       0.0    0.000000     0.000000   0.000000          True       solar
# 60       0.0    0.000000     0.000000   0.000000          True       solar
# 64       0.0   38.484861    38.484861   0.000000          True        wind
# 65       0.0  180.602933   180.602933   0.000000          True        wind
# 79       0.0    0.000000   916.200000  50.330000          True         gas
# 86       0.0    0.000000   360.000000  50.330000          True         gas
# 88       0.0    0.000000  1146.600000  50.330000          True         gas
# 99       0.0    0.000000  1175.400000  50.330000          True         gas
# 102      0.0    0.000000   194.400000  50.330000          True         gas
# 110      0.0    0.000000   142.200000  50.330000          True         gas

# %% [markdown]
# For the load nodes, the only important parameter is the demand $d_i \geq 0$. All other parameters are either zero, `False`, or an empty string `''`.

# %%
example_nodes[~example_nodes.is_generator]
# Out:
#                   d  p_min  p_max  c_var  is_generator energy_type
# node_id
# 0         28.186145    0.0    0.0    0.0         False
# 1         10.921628    0.0    0.0    0.0         False
# 2         22.884795    0.0    0.0    0.0         False
# 3         21.961682    0.0    0.0    0.0         False
# 4          0.000000    0.0    0.0    0.0         False
# ...             ...    ...    ...    ...           ...         ...
# 113        4.396000    0.0    0.0    0.0         False
# 114       11.864042    0.0    0.0    0.0         False
# 115      108.311328    0.0    0.0    0.0         False
# 116       10.703998    0.0    0.0    0.0         False
# 117       18.242759    0.0    0.0    0.0         False
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Edges

# %% [markdown]
# The IEEE-118 network has 179 edges. Each edge has the following parameters:
# - `node_id1`: first node of a given edge
# - `node_id2`: second node of a given edge
# - `b`: the line susceptance, and
# - `f_max`: the maximum edge capacity.

# %%
edges_df
# Out:
#                           b  f_max
# node_id1 node_id2
# 0        1          10.0100    271
#          2          23.5849    271
# 3        4         125.3133    316
# 2        4           9.2593    315
# 4        5          18.5185    316
# ...                     ...    ...
# 64       65         28.9059   1427
# 67       68         28.9059   1427
# 80       79         28.9059   1427
# 86       85          4.8216    253
# 67       115       246.9136  12992
#
# [179 rows x 2 columns]

# %% [markdown]
# ### Instances
# Since the OPF problem is solved every 15 minutes in practice, you will be given `24 * 4 = 96` network instances that need to be solved, hence solving an entire day's worth of OPF problems. The first instance thus corresponds to the power generation within time window `[00:00, 00:15]`, the second instance corresponds to `[00:15, 00:30]`, and so on. The data takes into account a realistic demand and (renewable energy) generation pattern. We assume that the decisions in each time window are independent of the previous and subsequent time windows, so every 15 minutes a new OPF instance is solved independently.
#
# The network instances are stored in the variable `I` as a list and can be accessed using indexing, i.e., `I[0]` gives the first network instance and `I[95]` gives the 96th network instance.

# %% [markdown]
# ---

# %% [markdown]
# # Solving OPF
# Observe that the stated OPF problem contains absolute decision values. We first rewrite the OPF problem into a linear optimization problem.
#
# $$\begin{align}
# \begin{array}{llll}
# \min        & \sum_{i \in V} c_i p_i \\
# \text{s.t.} & \sum_{j: (i, j) \in E} f^+_{ij} - f^-_{ij} - \sum_{j: (j, i) \in E} f^+_{ji} - f_{ji}^- = p_i - d_i & \forall \, i \in V,\\
# & f^+_{ij} - f^-_{ij} =  b_{ij}(\theta_i - \theta_j), & \forall \, (i, j) \in E, \\
#             & f^+_{ij} + f^-_{ij} \leq  f_{ij}^{\max}    & \forall (i, j) \in E,\\
#             & p_{i}^{\min } \leq p_{i} \leq p_{i}^{\max }         & \forall i \in V, \\
#             & p_i \in \mathbb{R}_{\geq 0}        & \forall i \in V,                \\
#             & \theta_i \in \mathbb{R} & \forall i \in V, \\
#             & f_{ij}^+, f_{ij}^- \in \mathbb{R}                 & \forall (i, j) \in E                \\
# \end{array}
# \end{align}$$
#
# We then implement the model using `AMPL` and solve it for all instances `I[0]` to `I[95]`, reporting the average objective value across all the 96 instances.

# %%
# %%writefile opf1.mod
#
# # Indexing sets
# set NODES;
# set EDGES within {NODES,NODES};
#
# # Parameters
# param d{NODES};
# param p_min{NODES};
# param p_max{NODES};
# param c_var{NODES};
# param is_generator{NODES};
# param energy_type{NODES} symbolic;
#
# param b{EDGES};
# param f_max{EDGES};
#
# # Declare decision variables
# var p{i in NODES} >= p_min[i], <= p_max[i];
# var theta{NODES};
# var fabs{(i,j) in EDGES} >= 0, <= f_max[i, j];
# var fp{EDGES} >= 0;
# var fm{EDGES} >= 0;
#
# # Declare objective value
# minimize energy_cost: sum{i in NODES: is_generator[i] == 1} c_var[i] * p[i];
#
# # Auxiliary variables for incoming and outgoing flows
# var incoming_flow{i in NODES} = sum{j in NODES: (j,i) in EDGES} (fp[j, i] - fm[j, i]);
# var outgoing_flow{i in NODES} = sum{j in NODES: (i,j) in EDGES} (fp[i, j] - fm[i, j]);
#
# # Constraints
# s.t. flow_conservation{i in NODES}:
#     outgoing_flow[i] - incoming_flow[i] == p[i] - d[i];
#
# s.t. susceptance{(i,j) in EDGES}:
#     fp[i, j] - fm[i, j] == b[i, j] * (theta[i] - theta[j]);
#
# s.t. abs_flow{(i,j) in EDGES}:
#     fabs[i, j] == fp[i, j] + fm[i, j];
# Out:
# Overwriting opf1.mod

# %%
def OPF1(network):
    """
    Input:
    - network: a dictionary containing:
      - a dictionary of nodes with a dictionary of attributes
      - a dictionary of edges with a dictionary of attributes

    Output:
    - total energy dispatching cost
    """

    nodes = network["nodes"]
    edges = network["edges"]

    m = AMPL()
    m.read("opf1.mod")

    m.set_data(nodes, "NODES")
    m.set_data(edges, "EDGES")

    m.solve(solver=SOLVER)
    assert m.solve_result == "solved", m.solve_result

    return m.obj["energy_cost"].value()

# %%
OPF1_results = [OPF1(instance) for instance in I]
print(f"The average objective value over all instances is: {np.mean(OPF1_results):.2f}")
# Out:
# HiGHS 1.11.0: optimal solution; objective 25556.38586
# 409 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 25291.14543
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 25014.46578
# 467 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 24033.92447
# 422 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 24607.51391
# 428 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 23894.80106
# 438 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 23539.85465
# 435 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 23344.3297
# 463 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 22863.0752
# 420 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 21810.52787
# 435 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 21900.80263
# 427 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 21547.3871
# 441 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 20462.85553
# 431 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 20203.29637
# 435 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 19631.87938
# 423 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 19053.61942
# 444 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 19052.65246
# 433 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 19361.24172
# 418 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 19838.31763
# 436 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 20490.77796
# 438 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 20961.18848
# 430 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 21810.71275
# 445 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 23204.42688
# 435 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 23961.68452
# 423 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 25710.80611
# 426 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 28528.05224
# 412 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 30606.15924
# 425 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 32931.97675
# 420 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 35933.96987
# 436 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 40878.89847
# 434 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 41272.13149
# 461 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 41625.78447
# 436 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 43657.80972
# 463 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 44523.08766
# 434 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 46653.79048
# 454 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 48123.99084
# 465 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 49986.24726
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 51594.08932
# 465 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 48767.34223
# 438 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 46412.44208
# 468 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 45234.51683
# 449 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 47192.70567
# 435 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 44287.62719
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 44509.58397
# 439 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 42934.44805
# 441 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 42869.82759
# 447 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 39555.8754
# 450 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 38670.71153
# 429 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 37154.52425
# 453 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36860.74842
# 441 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 38740.0701
# 458 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36354.1365
# 433 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36912.55781
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 37668.23898
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 37040.66645
# 427 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 34794.47952
# 433 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36325.10891
# 437 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36452.65775
# 436 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 35163.06581
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 35116.35087
# 444 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36112.04806
# 447 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 34697.75853
# 440 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 35180.60733
# 431 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 35021.77992
# 428 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36530.09028
# 428 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 37554.629
# 445 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 41679.08392
# 442 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 46836.06918
# 447 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 54206.38573
# 455 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 57125.77445
# 450 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 59781.78181
# 443 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 62049.83588
# 461 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 61861.88082
# 434 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 62773.3659
# 452 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 63568.70959
# 440 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 63537.75177
# 458 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 65871.0868
# 473 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 64744.56999
# 460 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 64044.66726
# 502 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 62795.39073
# 477 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 60679.41848
# 483 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 60587.38654
# 492 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 56395.11375
# 450 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 54159.88066
# 434 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 51612.43852
# 440 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 47266.24936
# 453 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 43900.49913
# 437 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 40067.91939
# 489 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 36097.07305
# 446 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 34979.65852
# 467 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 34133.27621
# 428 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 33746.40968
# 424 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 32602.68668
# 424 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 31745.40199
# 440 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 30839.27015
# 435 simplex iterations
# 0 barrier iterations
# HiGHS 1.11.0: optimal solution; objective 29427.14541
# 426 simplex iterations
# 0 barrier iterations
# The average objective value over all instances is: 38507.23

# %% [markdown]
# # Strict fossil fuel policy pt.1
# Gas and coal plants emit CO2, while renewable energy sources are carbon neutral. For this reason, the Dutch government has decided to constrain the number of active fossil-fuel-based power plants for the generation of electricity. More specifically, a maximum of 2 gas plants and 1 coal plant may be *active* during a single OPF instance. Any plant that is set *inactive* for a specific instance cannot produce any electricity.
#
# We first write down the new model. To this end, we introduce new decision variables $x_i, i\in V$ to the model, which indicate whether a generator $i$ is active or inactive.
#
# $$\begin{align}
# \begin{array}{llll}
# \min        & \sum_{i \in V} c_i p_i \\
# \text{s.t.} & \sum_{j: (i, j) \in E} f^+_{ij} - f^-_{ij} - \sum_{j: (j, i) \in E} f^+_{ji} - f_{ji}^- = p_i - d_i & \forall \, i \in V,\\
# & f^+_{ij} - f^-_{ij} =  b_{ij}(\theta_i - \theta_j), & \forall \, (i, j) \in E, \\
# & f^{abs}_{ij} = f^+_{ij} + f^-_{ij}, & \forall \, (i, j) \in E, \\
#             & f_{ij}^{abs} \leq  f_{ij}^{\max}    & \forall (i, j) \in E,\\
#             & p_{i}^{\min } x_i \leq p_{i} \leq p_{i}^{\max } x_i        & \forall i \in V, \\
#             & \sum_{i \in \mathcal{G}_{\text{gas}}} x_i \leq 2 & \\
#             & \sum_{i \in \mathcal{G}_{\text{coal}}} x_i \leq 1 &  \\
#             & p_i \in \mathbb{R}_{\geq 0}        & \forall i \in V,                \\
#             & \theta_i \in \mathbb{R} & \forall i \in V, \\
#             & f_{ij} \in \mathbb{R}                 & \forall (i, j) \in E                \\
#             & x_i  \in \{0, 1\} & \forall i \in V\\
# \end{array}
# \end{align}$$
#
# We then implement the new model using `AMPL` and solve it for all instances `I[0]` to `I[95]`, reporting the average objective value across the instances.

# %%
# %%writefile opf2.mod
#
# # Indexing sets
# set NODES;
# set EDGES within {NODES,NODES};
#
# # Parameters
# param d{NODES};
# param p_min{NODES};
# param p_max{NODES};
# param c_var{NODES};
# param is_generator{NODES};
# param energy_type{NODES} symbolic;
#
# param b{EDGES};
# param f_max{EDGES};
#
# param max_gas_plants;
# param max_coal_plants;
#
# # Declare decision variables
# var p{i in NODES} >= 0;
# var theta{NODES};
# var x{NODES} binary;
# var fabs{(i,j) in EDGES} >= 0, <= f_max[i, j];
# var fp{EDGES} >= 0;
# var fm{EDGES} >= 0;
#
# # Declare objective value
# minimize energy_cost: sum{i in NODES: is_generator[i] == 1} c_var[i] * p[i];
#
# # Auxiliary variables for incoming and outgoing flows
# var incoming_flow{i in NODES} = sum{j in NODES: (j,i) in EDGES} (fp[j, i] - fm[j, i]);
# var outgoing_flow{i in NODES} = sum{j in NODES: (i,j) in EDGES} (fp[i, j] - fm[i, j]);
#
# # Constraints
# s.t. flow_conservation{i in NODES}:
#     outgoing_flow[i] - incoming_flow[i] == p[i] - d[i];
#
# s.t. susceptance{(i,j) in EDGES}:
#     fp[i, j] - fm[i, j] == b[i, j] * (theta[i] - theta[j]);
#
# s.t. abs_flow{(i,j) in EDGES}:
#     fabs[i, j] == fp[i, j] + fm[i, j];
#
# s.t. generation_upper_bound{i in NODES}: p[i] <= p_max[i] * x[i];
# s.t. generation_lower_bound{i in NODES}: p[i] >= p_min[i] * x[i];
#
# s.t. gas_plants_limit: sum{i in NODES: energy_type[i] == 'gas'} x[i] <= max_gas_plants;
# s.t. coal_plants_limit: sum{i in NODES: energy_type[i] == 'coal'} x[i] <= max_coal_plants;
# Out:
# Overwriting opf2.mod

# %%
def OPF2(network, max_gas_plants, max_coal_plants):
    """
    Input:
    - network: a dictionary containing:
      - a dictionary of nodes with a dictionary of attributes
      - a dictionary of edges with a dictionary of attributes

    Output:
    - total energy dispatching cost
    """

    nodes = network["nodes"]
    edges = network["edges"]

    m = AMPL()
    m.read("opf2.mod")

    m.set_data(nodes, "NODES")
    m.set_data(edges, "EDGES")

    m.param["max_gas_plants"] = max_gas_plants
    m.param["max_coal_plants"] = max_coal_plants

    m.solve(solver=SOLVER)
    assert m.solve_result == "solved", m.solve_result

    return m.obj["energy_cost"].value()

# %%
max_gas_plants = 2
max_coal_plants = 1
OPF2_results = [OPF2(instance, max_gas_plants, max_coal_plants) for instance in I]
print(f"The average objective value over all instances is: {np.mean(OPF2_results):.2f}")
# Out:
# HiGHS 1.11.0: optimal solution; objective 32014.85844
# 483 simplex iterations
# 1 branching nodes
# absmipgap=7.27596e-11, relmipgap=2.27268e-15
# HiGHS 1.11.0: optimal solution; objective 31513.92689
# 495 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 30885.43208
# 478 simplex iterations
# 1 branching nodes
# absmipgap=2.874e-10, relmipgap=9.30537e-15
# HiGHS 1.11.0: optimal solution; objective 28881.74194
# 477 simplex iterations
# 1 branching nodes
# absmipgap=1.01863e-10, relmipgap=3.52691e-15
# HiGHS 1.11.0: optimal solution; objective 30037.14784
# 491 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 28659.49442
# 552 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 28098.31029
# 590 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 27643.13369
# 607 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 26906.38333
# 580 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 25000.0886
# 640 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 25172.05815
# 627 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 24597.59628
# 619 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 22704.40086
# 548 simplex iterations
# 1 branching nodes
# absmipgap=0.563366, relmipgap=2.48131e-05
# HiGHS 1.11.0: optimal solution; objective 22272.96622
# 482 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 21282.46505
# 717 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20149.63104
# 618 simplex iterations
# 4 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20299.75691
# 608 simplex iterations
# 4 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20796.63521
# 696 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 21606.25852
# 499 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 22744.74502
# 547 simplex iterations
# 1 branching nodes
# absmipgap=0.554562, relmipgap=2.4382e-05
# HiGHS 1.11.0: optimal solution; objective 23499.3076
# 710 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 25010.50854
# 592 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 27655.6242
# 611 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 28739.85416
# 545 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 32306.05117
# 446 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 38259.59372
# 483 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 42596.56579
# 470 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47474.46445
# 448 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52182.27728
# 458 simplex iterations
# 1 branching nodes
# absmipgap=5.74801e-10, relmipgap=1.10152e-14
# HiGHS 1.11.0: optimal solution; objective 57946.94606
# 477 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 58983.93317
# 503 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 59611.09337
# 498 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 62318.4829
# 545 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 63377.649
# 494 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 66355.25327
# 466 simplex iterations
# 1 branching nodes
# absmipgap=7.27596e-11, relmipgap=1.09652e-15
# HiGHS 1.11.0: optimal solution; objective 67718.3282
# 467 simplex iterations
# 1 branching nodes
# absmipgap=2.91038e-11, relmipgap=4.29778e-16
# HiGHS 1.11.0: optimal solution; objective 70199.13353
# 461 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 72074.24181
# 485 simplex iterations
# 1 branching nodes
# absmipgap=5.82077e-11, relmipgap=8.07607e-16
# HiGHS 1.11.0: optimal solution; objective 69357.83301
# 483 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 66541.23238
# 499 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 65359.14645
# 471 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 67603.72994
# 491 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 64424.45835
# 465 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 64578.61294
# 466 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 62683.24322
# 474 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 62712.94063
# 481 simplex iterations
# 1 branching nodes
# absmipgap=2.91038e-11, relmipgap=4.6408e-16
# HiGHS 1.11.0: optimal solution; objective 58810.9962
# 468 simplex iterations
# 1 branching nodes
# absmipgap=1.38243e-10, relmipgap=2.35064e-15
# HiGHS 1.11.0: optimal solution; objective 57847.89312
# 502 simplex iterations
# 1 branching nodes
# absmipgap=4.58385e-10, relmipgap=7.92398e-15
# HiGHS 1.11.0: optimal solution; objective 54468.61779
# 469 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 54196.02103
# 480 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 56244.40675
# 475 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52907.81025
# 470 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 53769.82573
# 469 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 55263.93141
# 482 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 54378.86264
# 489 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 50680.88639
# 464 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 53087.4615
# 481 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52929.63938
# 471 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51552.75812
# 457 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51058.5326
# 491 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52840.59651
# 480 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 50645.90154
# 471 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51995.97075
# 476 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51721.08012
# 465 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 54156.67505
# 488 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 55970.40312
# 491 simplex iterations
# 1 branching nodes
# absmipgap=3.63798e-11, relmipgap=6.49983e-16
# HiGHS 1.11.0: optimal solution; objective 61124.14254
# 473 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 67438.51907
# 482 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 75846.37597
# 485 simplex iterations
# 1 branching nodes
# absmipgap=1.45519e-11, relmipgap=1.9186e-16
# HiGHS 1.11.0: optimal solution; objective 79266.53736
# 508 simplex iterations
# 1 branching nodes
# absmipgap=2.47383e-10, relmipgap=3.1209e-15
# HiGHS 1.11.0: optimal solution; objective 82505.30565
# 607 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 85139.05154
# 503 simplex iterations
# 1 branching nodes
# absmipgap=4.36557e-11, relmipgap=5.12758e-16
# HiGHS 1.11.0: optimal solution; objective 84584.98267
# 495 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 85269.31644
# 494 simplex iterations
# 1 branching nodes
# absmipgap=2.91038e-11, relmipgap=3.41317e-16
# HiGHS 1.11.0: optimal solution; objective 86348.42938
# 492 simplex iterations
# 1 branching nodes
# absmipgap=4.36557e-11, relmipgap=5.05577e-16
# HiGHS 1.11.0: optimal solution; objective 86331.61954
# 494 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 88598.84186
# 469 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 87298.4441
# 479 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 86180.15407
# 447 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 84762.76321
# 478 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 82124.08662
# 467 simplex iterations
# 1 branching nodes
# absmipgap=1.45519e-11, relmipgap=1.77194e-16
# HiGHS 1.11.0: optimal solution; objective 82071.14498
# 479 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 77315.23968
# 509 simplex iterations
# 1 branching nodes
# absmipgap=1.16415e-10, relmipgap=1.50572e-15
# HiGHS 1.11.0: optimal solution; objective 74464.39753
# 559 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 71600.93405
# 513 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 66396.59052
# 526 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 62377.56686
# 488 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 57665.26521
# 465 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 53248.29462
# 477 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51707.5513
# 445 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 50039.81283
# 487 simplex iterations
# 1 branching nodes
# absmipgap=1.45519e-11, relmipgap=2.90807e-16
# HiGHS 1.11.0: optimal solution; objective 49235.30303
# 458 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46856.8694
# 440 simplex iterations
# 1 branching nodes
# absmipgap=5.02041e-10, relmipgap=1.07144e-14
# HiGHS 1.11.0: optimal solution; objective 45074.09967
# 447 simplex iterations
# 1 branching nodes
# absmipgap=7.27596e-12, relmipgap=1.61422e-16
# HiGHS 1.11.0: optimal solution; objective 43164.18792
# 477 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 40195.99971
# 479 simplex iterations
# 1 branching nodes
# The average objective value over all instances is: 53120.81

# %% [markdown]
# # Strict fossil fuel policy pt.2
# The restriction on the number of gas and coal plants may pose a threat to the availability of electricity production when renewable energy sources fail to deliver. For this reason, the grid operators have decided to slightly change the constraint that was introduced for OPF2. If the total production of energy from renewable energy sources (i.e., solar, wind and hydro) is above 1000, then the number of gas and coal plants is restricted to 2 and 1, respectively. Otherwise, the restriction on the number of gas and coal plants is lifted. These constraints can be modeled as *either-or* constraints.
#
# We first write down the new model, using big-$M$ constraints to model the either-or constraint.
#
# $$\begin{align}
# \begin{array}{llll}
# \min        & \sum_{i \in V} c_i p_i \\
# \text{s.t.} & \sum_{j: (i, j) \in E} f^+_{ij} - f^-_{ij} - \sum_{j: (j, i) \in E} f^+_{ji} - f_{ji}^- = p_i - d_i & \forall \, i \in V,\\
# & f^+_{ij} - f^-_{ij} =  b_{ij}(\theta_i - \theta_j), & \forall \, (i, j) \in E, \\
# & f^{abs}_{ij} = f^+_{ij} + f^-_{ij}, & \forall \, (i, j) \in E, \\
#             & f_{ij}^{abs} \leq  f_{ij}^{\max}    & \forall (i, j) \in E,\\
#             & p_{i}^{\min } x_i \leq p_{i} \leq p_{i}^{\max } x_i        & \forall i \in V, \\
#             & \sum_{i \in \mathcal{G}_{\text{gas}}} x_i \leq 2 + (1-y)M_0 & \\
#             & \sum_{i \in \mathcal{G}_{\text{coal}}} x_i \leq 1 + (1-y)M_1 &  \\
#             & \sum_{i \in \mathcal{G}_\text{solar}} p_i + \sum_{i \in \mathcal{G}_\text{wind}} p_i + \sum_{i \in \mathcal{G}_\text{hydro}} p_i \leq 1000 + yM_2&\\
#             & p_i \in \mathbb{R}_{\geq 0}        & \forall i \in V,                \\
#             & \theta_i \in \mathbb{R} & \forall i \in V, \\
#             & f_{ij} \in \mathbb{R}                 & \forall (i, j) \in E                \\
#             & x_i  \in \{0, 1\} & \forall i \in V\\
#             & y \in \{0, 1\} &\\
# \end{array}
# \end{align}$$
#
# We now implement the new model using `AMPL` and solve it for all instances `I[0]` to `I[95]`, reporting the average objective value across the instances.

# %%
# %%writefile opf3.mod
#
# # Indexing sets
# set NODES;
# set EDGES within {NODES,NODES};
#
# # Parameters
# param d{NODES};
# param p_min{NODES};
# param p_max{NODES};
# param c_var{NODES};
# param is_generator{NODES};
# param energy_type{NODES} symbolic;
#
# param b{EDGES};
# param f_max{EDGES};
#
# param max_gas_plants;
# param max_coal_plants;
#
# # Big-Ms
# param M0;
# param M1;
# param M2;
#
# # Declare decision variables
# var p{i in NODES} >= 0;
# var theta{NODES};
# var x{NODES} binary;
# var fabs{(i,j) in EDGES} >= 0, <= f_max[i, j];
# var fp{EDGES} >= 0;
# var fm{EDGES} >= 0;
# var y binary;
#
# # Declare objective value
# minimize energy_cost: sum{i in NODES: is_generator[i] == 1} c_var[i] * p[i];
#
# # Auxiliary variables for incoming and outgoing flows
# var incoming_flow{i in NODES} = sum{j in NODES: (j,i) in EDGES} (fp[j, i] - fm[j, i]);
# var outgoing_flow{i in NODES} = sum{j in NODES: (i,j) in EDGES} (fp[i, j] - fm[i, j]);
#
# # Constraints
# s.t. flow_conservation{i in NODES}:
#     outgoing_flow[i] - incoming_flow[i] == p[i] - d[i];
#
# s.t. susceptance{(i,j) in EDGES}:
#     fp[i, j] - fm[i, j] == b[i, j] * (theta[i] - theta[j]);
#
# s.t. abs_flow{(i,j) in EDGES}:
#     fabs[i, j] == fp[i, j] + fm[i, j];
#
# s.t. generation_upper_bound{i in NODES}: p[i] <= p_max[i] * x[i];
# s.t. generation_lower_bound{i in NODES}: p[i] >= p_min[i] * x[i];
#
# s.t. gas_plants_limit: sum{i in NODES: energy_type[i] == 'gas'} x[i] <= max_gas_plants + (1 - y) * M0;
#
# s.t. coal_plants_limit: sum{i in NODES: energy_type[i] == 'coal'} x[i] <= max_coal_plants + (1 - y) * M1;
#
# s.t. renewable_energy_production:
#     sum{i in NODES: energy_type[i] in {'solar', 'wind', 'hydro'}} p[i] <= 1000 + y * M2;
# Out:
# Overwriting opf3.mod

# %%
def OPF3(network, max_gas_plants, max_coal_plants):
    """
    Input:
    - network: a dictionary containing:
      - a dictionary of nodes with a dictionary of attributes
      - a dictionary of edges with a dictionary of attributes

    Output:
    - total energy dispatching cost
    """

    nodes = network["nodes"]
    edges = network["edges"]

    m = AMPL()
    m.read("opf3.mod")

    m.set_data(nodes, "NODES")
    m.set_data(edges, "EDGES")

    m.param["max_gas_plants"] = max_gas_plants
    m.param["max_coal_plants"] = max_coal_plants

    m.param["M0"] = 4
    m.param["M1"] = 3
    m.param["M2"] = nodes["p_max"].sum()

    m.solve(solver=SOLVER)
    assert m.solve_result == "solved", m.solve_result

    return m.obj["energy_cost"].value()

# %%
OPF3_results = [OPF3(instance, max_gas_plants, max_coal_plants) for instance in I]
print(f"The average objective value over all instances is: {np.mean(OPF3_results):.2f}")
# Out:
# HiGHS 1.11.0: optimal solution; objective 25556.38586
# 427 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 25291.14543
# 432 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 25014.46578
# 431 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 24033.92447
# 448 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 24607.51391
# 432 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 23894.80106
# 425 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 23539.85465
# 426 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 23344.3297
# 422 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 22863.0752
# 439 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 21810.52787
# 429 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 21900.80263
# 431 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 21547.3871
# 435 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20462.85553
# 447 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20203.29637
# 429 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 19631.87938
# 420 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 19053.61942
# 434 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 19052.65246
# 430 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 19361.24172
# 431 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 19838.31763
# 439 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20490.77796
# 421 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 20961.18848
# 444 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 21810.71275
# 432 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 23204.42688
# 426 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 23961.68452
# 439 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 25710.80611
# 434 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 28528.05224
# 440 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 30606.15924
# 448 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 32931.97675
# 436 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 35933.96987
# 427 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 40878.89847
# 465 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 41272.13149
# 439 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 41625.78447
# 438 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 43657.80972
# 456 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 44523.08766
# 429 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46653.79048
# 441 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 48517.02462
# 477 simplex iterations
# 1 branching nodes
# absmipgap=5.82077e-11, relmipgap=1.19974e-15
# HiGHS 1.11.0: optimal solution; objective 51469.76795
# 482 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 53735.57811
# 615 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52478.34218
# 484 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51082.21976
# 505 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 50820.70479
# 493 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52284.09621
# 501 simplex iterations
# 1 branching nodes
# absmipgap=1.23691e-10, relmipgap=2.36575e-15
# HiGHS 1.11.0: optimal solution; objective 51770.03428
# 635 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52556.32959
# 1044 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 52063.08667
# 1356 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 50973.40711
# 1449 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 49101.46232
# 1001 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47859.57387
# 1205 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47812.22458
# 1268 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47735.03354
# 1004 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 49249.56069
# 1155 simplex iterations
# 10 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47079.99596
# 924 simplex iterations
# 11 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47106.46001
# 1186 simplex iterations
# 9 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47698.24825
# 1321 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47740.93595
# 926 simplex iterations
# 5 branching nodes
# HiGHS 1.11.0: optimal solution; objective 45854.74172
# 938 simplex iterations
# 10 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46738.37993
# 957 simplex iterations
# 7 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46817.47832
# 942 simplex iterations
# 9 branching nodes
# HiGHS 1.11.0: optimal solution; objective 45851.54466
# 963 simplex iterations
# 7 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46189.99144
# 964 simplex iterations
# 7 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46339.28074
# 1090 simplex iterations
# 9 branching nodes
# HiGHS 1.11.0: optimal solution; objective 45723.75827
# 1009 simplex iterations
# 9 branching nodes
# HiGHS 1.11.0: optimal solution; objective 44508.52721
# 1122 simplex iterations
# 7 branching nodes
# HiGHS 1.11.0: optimal solution; objective 44574.67924
# 961 simplex iterations
# 3 branching nodes
# absmipgap=0.500375, relmipgap=1.12255e-05
# HiGHS 1.11.0: optimal solution; objective 46015.12654
# 1243 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 46672.0612
# 868 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 49744.16264
# 1151 simplex iterations
# 7 branching nodes
# HiGHS 1.11.0: optimal solution; objective 54261.30821
# 621 simplex iterations
# 3 branching nodes
# HiGHS 1.11.0: optimal solution; objective 59898.76421
# 602 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 62696.04055
# 661 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 63259.92706
# 534 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 65614.15585
# 591 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 64099.97548
# 552 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 63826.39248
# 482 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 63624.76669
# 498 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 63537.75177
# 455 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 65871.0868
# 474 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 64744.56999
# 461 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 64044.66726
# 463 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 62795.39073
# 473 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 60679.41848
# 459 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 60587.38654
# 444 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 56395.11375
# 433 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 54159.88066
# 447 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 51612.43852
# 440 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 47266.24936
# 441 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 43900.49913
# 429 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 40067.91939
# 449 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 36097.07305
# 437 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 34979.65852
# 443 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 34133.27621
# 440 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 33746.40968
# 432 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 32602.68668
# 430 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 31745.40199
# 440 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 30839.27015
# 446 simplex iterations
# 1 branching nodes
# HiGHS 1.11.0: optimal solution; objective 29427.14541
# 431 simplex iterations
# 1 branching nodes
# The average objective value over all instances is: 41608.73

# %% [markdown]
# # Comparing the three models
# For all three implemented models, we plot the objective values for all instances and explain the differences between the objective values in view of the different feasible regions.

# %%
objs = [OPF1_results, OPF2_results, OPF3_results]

# %%
plt.plot(objs[0], color="blue", label="OPF1")
plt.plot(objs[1], color="green", label="OPF2")
plt.plot(objs[2], color="orange", label="OPF3")
plt.title("Optimal objective values over all instances and models")
plt.xlabel("Instance number")
plt.ylabel("Optimal objective value")
plt.legend()
plt.show()

# %% [markdown]
# The goal of the OPF problem is to minimize the total costs of dispatching energy. OPF1 is the original OPF formulation, whereas OPF2 and OPF3 are restricted versions of OPF1. This means that the feasible region of OPF1 is at least as large as OPF2 and OPF3, where we may assume that $x_i = 1$ for all the generators $i$.
#
# If we let $F_1, F_2, F_3$ denote the feasible region of OPF1, OPF2 and OPF3, then we observe that which explains that the optimal objective value of OPF1 always remains below the optimal objectives values of OPF2 and OPF3.
#
# The most important observation to make is that based on the problem descriptions, we would expect OPF2 to take on the objective values of OPF1 or OPF3, depending on which of the either-or-constraints are activated.
# - OPF3 uses expensive generators, and possibly not all the renewable energy
# - OPF2 does only uses 1000 renewable energy power, because then it may keep using all the gas and coal generators.
# - OPF1 uses all renewable energy at all times, because it has the flexibility to use all generators in order to mitigate operational restrictions due to line flows.
